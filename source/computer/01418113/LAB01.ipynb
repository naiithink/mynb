# %%
from __future__ import print_function, with_statement
from IPython.display import display, HTML, Markdown
from pygments import highlight
from pygments.formatters import HtmlFormatter
from pygments.lexers import CLexer

# %% [markdown]
# # LAB01
#
# 01418113-LAB

# %%
script = r"""
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
    }

    function getCompilerMsg() {
        const q01_cm = null;
        if (q01_cm) {
            document.getElementById("q01_cm01").innerHTML = q01_cm;
        } else {
            document.getElementById("q01_cm01").innerHTML = "Nothing to see here.";
        }
    }
</script>
"""

style = r"""
<style>
    textarea.singleline {
        height: 1em;
        overflow: hidden;
        resize: none;
    }

    th, td {
        text-align: left;
    }
</style>
"""

src1 = r"""
# 01 คอมพิวเตอร์ทำงาน

จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br>
เมื่อตัวแปร `computer_time` เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br>
<br>

**ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 785**<br>

```
It is 0 days 13 hours and 5 minutes.
```

อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br>

**ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 1678**<br>

```
It is 1 days 3 hours and 58 minutes.
```

อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที

---
"""

code1 = r"""
<div class="highlight">
<pre>
#include&lt;stdio.h&gt;
void main() {
    int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
<textarea id="q01_a01_01" rows="7" cols="97">
    int days = computer_time / 1440;
    int hours = (computer_time - days * 1440) / 60;
    int mins = computer_time - (days * 1440 + hours * 60);
    printf("It is %i days %i hours and %i minutes.\n", days, hours, mins);
</textarea>
}
</pre>
</div>
<input type="button" onclick="submit()" value="Submit" />
<input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
"""

cmsg1 = """
<pre>
<p id="q01_cm01"></p>
</pre>
"""

got = r"""
<p id="gotten"></p>
"""

display(
    Markdown(src1),
    HTML(code1 + cmsg1 + got + style + script)
)
# Out:
# # 01 คอมพิวเตอร์ทำงาน
#
# จงเขียนโปรแกรมเพื่อแสดงผลเวลาที่เครื่องคอมพิวเตอร์ทำงานในรูปของจำนวนวัน ชั่วโมง และนาที ตามลำดับ (ไม่ต้องคำนึง)<br>
# เมื่อตัวแปร `computer_time` เก็บค่าจำนวนนาทีที่เครื่องคอมพิวเตอร์ทำงาน<br>
# <br>
#
# **ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 785**<br>
#
# ```
# It is 0 days 13 hours and 5 minutes.
# ```
#
# อธิบาย: คอมพิวเตอร์ทำงาน 785 นาที เท่ากับ 0 วัน 13 ชั่วโมง 5 นาที<br>
#
# **ตัวอย่างผลลัพธ์เมื่อ `computer_time` มีค่า 1678**<br>
#
# ```
# It is 1 days 3 hours and 58 minutes.
# ```
#
# อธิบาย: คอมพิวเตอร์ทำงาน 1678 นาที เท่ากับ 1 วัน 3 ชั่วโมง 58 นาที
#
# ---
# <div class="highlight">
# <pre>
# #include&lt;stdio.h&gt;
# void main() {
#     int computer_time = 785;  // ในโปรแกรมตรวจอาจเปลี่ยนค่าของตัวแปรนี้ แต่นิสิตไม่ต้องเปลี่ยนค่าของตัวแปรนี้
# <textarea id="q01_a01_01" rows="7" cols="97">
#     int days = computer_time / 1440;
#     int hours = (computer_time - days * 1440) / 60;
#     int mins = computer_time - (days * 1440 + hours * 60);
# ...

# %%
script = r"""
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
    }

    function getCompilerMsg() {
        const q02_cm = null;
        if (q02_cm) {
            document.getElementById("q02_cm01").innerHTML = q02_cm;
        } else {
            document.getElementById("q02_cm01").innerHTML = "Nothing to see here.";
        }
    }
</script>
"""

style = r"""
<style>
    textarea.singleline {
        height: 1em;
        overflow: hidden;
        resize: none;
    }

    th, td {
        text-align: left;
    }
</style>
"""

src1 = r"""
# 02 Sphere Volume

จงเขียนโปรแกรมเพื่อคำนวณค่าปริมาตร (volume) ของทรงกลม ในรูปแบบทศนิยม 2 ตำแหน่ง โดยค่ารัศมี (ตัวแปร `radius`) เป็นจำนวนจริง<br>
โดยใช้การคำนวณจากสูตร<br>

$$ volume = \frac{4}{3} \times \pi \times radius^{3} $$
กำหนดค่าคงที่ $ \pi = \frac{22}{7} $<br>

**ตัวอย่างผลลัพธ์ เมื่อตัวแปร `radius` มีค่า 1.5**<br>

```
The volume of this sphere is 14.14
```

---
"""

code1 = r"""
<div class="highlight">
<pre>
#include &lt;stdio.h&gt;
#include &lt;stdlib.h&gt;

// กำหนดค่าคงที่ PI มีค่า 22.0/7
#define PI 22.0/7

void main()
{
    float radius = 1.5;
<textarea id="q01_a01_01" rows="6" cols="103">
    float volume = (4.0 / 3.0) * PI * (radius * radius * radius);
    printf("The volume of this sphere is %.2f\n", volume);
</textarea>
}
</pre>
</div>
<input type="button" onclick="submit()" value="Submit" />
<input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
"""

cmsg1 = """
<pre>
<p id="q02_cm01"></p>
</pre>
"""

got1 = r"""
<p id="gotten"></p>
"""

display(
    Markdown(src1),
    HTML(code1 + cmsg1 + got1 + style + script)
)
# Out:
# # 02 Sphere Volume
#
# จงเขียนโปรแกรมเพื่อคำนวณค่าปริมาตร (volume) ของทรงกลม ในรูปแบบทศนิยม 2 ตำแหน่ง โดยค่ารัศมี (ตัวแปร `radius`) เป็นจำนวนจริง<br>
# โดยใช้การคำนวณจากสูตร<br>
#
# $$ volume = \frac{4}{3} \times \pi \times radius^{3} $$
# กำหนดค่าคงที่ $ \pi = \frac{22}{7} $<br>
#
# **ตัวอย่างผลลัพธ์ เมื่อตัวแปร `radius` มีค่า 1.5**<br>
#
# ```
# The volume of this sphere is 14.14
# ```
#
# ---
# <div class="highlight">
# <pre>
# #include &lt;stdio.h&gt;
# #include &lt;stdlib.h&gt;
#
# // กำหนดค่าคงที่ PI มีค่า 22.0/7
# #define PI 22.0/7
#
# void main()
# {
#     float radius = 1.5;
# <textarea id="q01_a01_01" rows="6" cols="103">
#     float volume = (4.0 / 3.0) * PI * (radius * radius * radius);
#     printf("The volume of this sphere is %.2f\n", volume);
# </textarea>
# }
# </pre>
# </div>
# <input type="button" onclick="submit()" value="Submit" />
# <input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
#
# <pre>
# <p id="q02_cm01"></p>
# </pre>
#
# ...

# %%
script = r"""
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
    }

    function getCompilerMsg() {
        const q03_cm = null;
        if (q03_cm) {
            document.getElementById("q03_cm01").innerHTML = q03_cm;
        } else {
            document.getElementById("q03_cm01").innerHTML = "Nothing to see here.";
        }
    }
</script>
"""

style = r"""
<style>
    textarea.singleline {
        height: 1em;
        overflow: hidden;
        resize: none;
    }

    th, td {
        text-align: left;
    }
</style>
"""

src1 = r"""
# 03 GPA Calculator

เขียนโปรแกรมเพื่อหาจำนวนเกรดเฉลี่ยที่ต้องทำในเทอมนี้ เพื่อให้ได้เกรดเฉลี่ยรวมที่ต้องการ<br>
โดยตัวแปรเก็บค่าต่าง ๆ ดังนี้<br>
`preGrade` เก็บค่า เกรดเฉลี่ยสะสมที่ผ่านมา<br>
`preCredit` เก็บค่า หน่วยกิตสะสมที่คำนวณเกรดเฉลี่ยแล้ว<br>
`credit` เก็บค่า หน่วยกิตของเทอมนี้<br>
`requiredGrade` เก็บค่า เกรดเฉลี่ยรวมที่ต้องการ

**หมายเหต**

- เกรดเฉลี่ยที่คำนวณมาได้ แสดงเป็นทศนิยม 2 ตำแหน่ง
- หน่วยกิตเป็นจำนวนเต็ม
- เกรดเฉลี่ยที่คำนวณมาได้อาจมีค่าเกิน 4.00 (เพราะหวังสูง แต่ของเก่าไม่มากพอ)

**ตัวอย่างผลลัพธ์ของค่าที่ปรากฏในโปรแกรม**<br>

```
The GPA this semester should be 2.29
```
อธิบาย: ลงทะเบียนเรียนไปแล้ว 21 หน่วยกิต ได้เกรดเฉลี่ยสะสม 1.75 และในเทอมนี้ลงทะเบียนเรียน 18 หน่วยกิต ต้องการเกรดเฉลี่ยสะสม 2.00 จึงต้องทำเกรดเฉลี่ยเทอมนี้ให้ได้ 2.29

---
"""

code1 = r"""
<div class="highlight">
<pre>
#include&lt;stdio.h&gt;
void main()
{
    <textarea class="singleline" id="q01_a01_01">float</textarea> preGrade = 1.15;
    <textarea class="singleline" id="q01_a01_02">int</textarea> preCredit = 21;
    <textarea class="singleline" id="q01_a01_03">int</textarea> credit = 18;
    <textarea class="singleline" id="q01_a01_04">float</textarea> requiredGrade = 2.00;

<textarea id="q01_a01_05" rows="7" cols="127">
    float preScore = preGrade * (preCredit / 1);
    float totalCredit = (preCredit / 1) + (credit / 1);
    float targetScore = (requiredGrade * totalCredit) - preScore;
    float targetGrade = targetScore / (credit / 1);

    printf("The GPA this semester should be %.2f\n", targetGrade);
</textarea>
}
</pre>
</div>
<input type="button" onclick="submit()" value="Submit" />
<input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
"""

cmsg1 = """
<pre>
<p id="q03_cm01"></p>
</pre>
"""

got1 = r"""
<p id="gotten"></p>
"""

display(
    Markdown(src1),
    HTML(code1 + cmsg1 + got1 + style + script)
)
# Out:
# # 03 GPA Calculator
#
# เขียนโปรแกรมเพื่อหาจำนวนเกรดเฉลี่ยที่ต้องทำในเทอมนี้ เพื่อให้ได้เกรดเฉลี่ยรวมที่ต้องการ<br>
# โดยตัวแปรเก็บค่าต่าง ๆ ดังนี้<br>
# `preGrade` เก็บค่า เกรดเฉลี่ยสะสมที่ผ่านมา<br>
# `preCredit` เก็บค่า หน่วยกิตสะสมที่คำนวณเกรดเฉลี่ยแล้ว<br>
# `credit` เก็บค่า หน่วยกิตของเทอมนี้<br>
# `requiredGrade` เก็บค่า เกรดเฉลี่ยรวมที่ต้องการ
#
# **หมายเหต**
#
# - เกรดเฉลี่ยที่คำนวณมาได้ แสดงเป็นทศนิยม 2 ตำแหน่ง
# - หน่วยกิตเป็นจำนวนเต็ม
# - เกรดเฉลี่ยที่คำนวณมาได้อาจมีค่าเกิน 4.00 (เพราะหวังสูง แต่ของเก่าไม่มากพอ)
#
# **ตัวอย่างผลลัพธ์ของค่าที่ปรากฏในโปรแกรม**<br>
#
# ```
# The GPA this semester should be 2.29
# ```
# อธิบาย: ลงทะเบียนเรียนไปแล้ว 21 หน่วยกิต ได้เกรดเฉลี่ยสะสม 1.75 และในเทอมนี้ลงทะเบียนเรียน 18 หน่วยกิต ต้องการเกรดเฉลี่ยสะสม 2.00 จึงต้องทำเกรดเฉลี่ยเทอมนี้ให้ได้ 2.29
#
# ---
# <div class="highlight">
# <pre>
# #include&lt;stdio.h&gt;
# void main()
# {
#     <textarea class="singleline" id="q01_a01_01">float</textarea> preGrade = 1.15;
# ...

# %%
script = r"""
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
    }

    function getCompilerMsg() {
        const q04_cm = null;
        if (q04_cm) {
            document.getElementById("q04_cm01").innerHTML = q04_cm;
        } else {
            document.getElementById("q04_cm01").innerHTML = "Nothing to see here.";
        }
    }
</script>
"""

style = r"""
<style>
    textarea.singleline {
        height: 1em;
        overflow: hidden;
        resize: none;
    }

    th, td {
        text-align: left;
    }
</style>
"""

src1 = r"""
# 04 Escape Squence (เพิ่มเติม)

## Escape Sequence

จงเติมคำสั่ง printf ข้างล่างให้มันพิมพ์ข้อความที่ปรากฏอยู่ที่ตารางช่องด้านซ้ายมือ

---
"""

code1 = r"""
<table>
    <thead>
        <tr>
            <th>ผลลัพธ์</th>
            <th>ตำสั่ง printf</th>
        </tr>
    </thead>
    <tbody>
        <tr>
            <td>
<pre>
x
xx
xxx
xx
x
</pre>
</td>
<td>
<pre>
printf(<textarea id="q01_a01_01" class="singleline" cols="68">&quot;x\\nxx\\nxxx\\n xx\\n  x&quot;</textarea>);
</pre>
            </td>
        </tr>
        <tr>
            <td>
<pre>
printf("Hello, world\n");
</pre>
            </td>
            <td>
<pre>
printf(<textarea id="q01_a01_02" class="singleline" cols="68">&quot;printf(&quot;Hello, world\\n&quot;);&quot;</textarea>);
</pre>
            </td>
        </tr>
    </tbody>
</table>
<br />
<input type="button" onclick="submit()" value="Submit" />
<input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
"""

cmsg1 = """
<pre>
<p id="q04_cm01"></p>
</pre>
"""

got1 = r"""
<p id="gotten"></p>
"""

display(
    Markdown(src1),
    HTML(code1 + cmsg1 + got1 + style + script)
)
# Out:
# # 04 Escape Squence (เพิ่มเติม)
#
# ## Escape Sequence
#
# จงเติมคำสั่ง printf ข้างล่างให้มันพิมพ์ข้อความที่ปรากฏอยู่ที่ตารางช่องด้านซ้ายมือ
#
# ---
# <table>
#     <thead>
#         <tr>
#             <th>ผลลัพธ์</th>
#             <th>ตำสั่ง printf</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
# <pre>
# x
# xx
# xxx
# xx
# x
# </pre>
# </td>
# <td>
# <pre>
# printf(<textarea id="q01_a01_01" class="singleline" cols="68">&quot;x\\nxx\\nxxx\\n xx\\n  x&quot;</textarea>);
# </pre>
#             </td>
#         </tr>
#         <tr>
#             <td>
# <pre>
# printf("Hello, world\n");
# </pre>
#             </td>
#             <td>
# <pre>
# printf(<textarea id="q01_a01_02" class="singleline" cols="68">&quot;printf(&quot;Hello, world\\n&quot;);&quot;</textarea>);
# </pre>
#             </td>
#         </tr>
#     </tbody>
# </table>
# <br />
# <input type="button" onclick="submit()" value="Submit" />
# ...

# %%
script = r"""
<script type="text/javascript">
    function submit() {
        var q01_a01_01 = document.getElementById("q01_a01_01").value;
        if (q01_a01_01) {
            document.getElementById("gotten").innerHTML = q01_a01_01;
        } else {
            document.getElementById("gotten").innerHTML = "Something went wrong.";
        }
    }

    function getCompilerMsg() {
        const q05_cm = null;
        if (q05_cm) {
            document.getElementById("q05_cm01").innerHTML = q05_cm;
        } else {
            document.getElementById("q05_cm01").innerHTML = "Nothing to see here.";
        }
    }
</script>
"""

style = r"""
<style>
    textarea.singleline {
        height: 1em;
        overflow: hidden;
        resize: none;
    }

    th, td {
        text-align: left;
    }
</style>
"""

src1 = r"""
# 05 ทอนเงิน (พิมพ์น้อยไปมาก)

## ทอนเงิน (อย่างง่าย)

สมมติว่ามีธนบัตรใบละ 50, 20, 5 และ 1 บาท ให้ตัวแปร `amount` เก็บค่าจำนวนเงินที่ต้องทอน (เป็นจำนวนเต็มเสมอ)<br>
แล้วแสดงผลลัพธ์เป็นจำนวนธนบัตรแต่ละชนิดที่ต้องทอน โดยกำหนดให้ทอนเป็นธนบัตรชนิดราคาสูงกว่าให้ได้มากที่สุดก่อน แต่ให้พิมพ์คำตอบเรียงลำดับจากธนบัตรชนิดราคาต่ำ ไปหาราคาสูงที่สุด

**ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 98**<br>

```
1: 3
5: 1
20: 2
50: 1
```

**ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 19**

```
1: 4
5: 3
20: 0
50: 0
```

**ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 50**

```
1: 0
5: 0
20: 0
50: 1
```

พิมพ์โปรแกรมของคุณลงในช่องว่างข้างล่างนี้

---
"""

code1 = r"""
<div class="highlight">
<pre>
#include &lt;stdio.h&gt;

int main()
{
  int amount = ...;
<br />
<textarea id="q01_a01_05" rows="14" cols="54">
    int noteTypes = 4;
    int notes[] = {50, 20, 5, 1};
    int remain = amount;
    int noteCount[noteTypes];

    for (int i = 0; i < noteTypes; i++)
    {
        if (remain >= notes[i])
        {
            noteCount[i] = remain / notes[i];
        }
        else
        {
            noteCount[i] = 0;
        }
        remain = remain - noteCount[i] * notes[i];
    }

    for (int i = noteTypes-1; i > -1; i--)
    {
        printf("%i: %i\n", notes[i], noteCount[i]);
    }
</textarea>
}
</pre>
</div>
<input type="button" onclick="submit()" value="Submit" />
<input type="button" onclick="getCompilerMsg()" value="View compiler messages" />
"""

cmsg1 = """
<pre>
<p id="q05_cm01"></p>
</pre>
"""

got1 = r"""
<p id="gotten"></p>
"""

display(
    Markdown(src1),
    HTML(code1 + cmsg1 + got1 + style + script)
)
# Out:
# # 05 ทอนเงิน (พิมพ์น้อยไปมาก)
#
# ## ทอนเงิน (อย่างง่าย)
#
# สมมติว่ามีธนบัตรใบละ 50, 20, 5 และ 1 บาท ให้ตัวแปร `amount` เก็บค่าจำนวนเงินที่ต้องทอน (เป็นจำนวนเต็มเสมอ)<br>
# แล้วแสดงผลลัพธ์เป็นจำนวนธนบัตรแต่ละชนิดที่ต้องทอน โดยกำหนดให้ทอนเป็นธนบัตรชนิดราคาสูงกว่าให้ได้มากที่สุดก่อน แต่ให้พิมพ์คำตอบเรียงลำดับจากธนบัตรชนิดราคาต่ำ ไปหาราคาสูงที่สุด
#
# **ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 98**<br>
#
# ```
# 1: 3
# 5: 1
# 20: 2
# 50: 1
# ```
#
# **ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 19**
#
# ```
# 1: 4
# 5: 3
# 20: 0
# 50: 0
# ```
#
# **ตัวอย่างผลลัพธ์เมื่อตัวแปร `amount` มีค่า 50**
#
# ```
# 1: 0
# 5: 0
# 20: 0
# 50: 1
# ```
#
# พิมพ์โปรแกรมของคุณลงในช่องว่างข้างล่างนี้
#
# ---
# <div class="highlight">
# <pre>
# #include &lt;stdio.h&gt;
#
# int main()
# {
#   int amount = ...;
# <br />
# <textarea id="q01_a01_05" rows="14" cols="54">
#     int noteTypes = 4;
#     int notes[] = {50, 20, 5, 1};
#     int remain = amount;
#     int noteCount[noteTypes];
#
# ...
